# %%
x = 42
x
# Out:
# 42

# %%
y = '34'

# %%
type(y)
# Out:
# str

# %%
x = 5
x = 4.1
x
# Out:
# 4.1

# %%
a = 5
b = 4.1
c = 2.9

a + b + c
# Out:
# 12.0

# %%
a  = 5
b = 2

div1 = a/b
div2 = a//b

# %%
print(f"simple division: {div1}")
print(f"integer division: {div2}")
# Out:
# simple division: 2.5
# integer division: 2

# %%
first_name = "Karen"
last_name = "Hovhannisyan"

# %%
type(first_name)
# Out:
# str

# %%
print(first_name)
# Out:
# Karen

# %%
a = '11'

# %%
a + '2'
# Out:
# '112'

# %%
full_name = first_name + ' ' + last_name
full_name
# Out:
# 'Karen Hovhannisyan'

# %%
N = 4
power = 3
for i in range(N):
    print(f'{i} power of {power} {i**power}')
# Out:
# 0 power of 3 0
# 1 power of 3 1
# 2 power of 3 8
# 3 power of 3 27

# %%
is_active1 = True
is_active2 = False

# %%
type(is_active1)
# Out:
# bool

# %%
x = 42

x> 40
# Out:
# True

# %%
x == 42
x<=42
# Out:
# True

# %%
x = '42'

# %%
x
# Out:
# '42'

# %%
x = 42
y = 32
z = x + y

type(x + y)
# Out:
# int

# %%
type(z)
# Out:
# int
