# %%
r = 568
tax_rate = 0.3

# %%
total = r * (1 + tax_rate)

# %%
total
# Out:
# 738.4

# %%
discount_rate = 0.10

# %%
final = r * (1 + tax_rate)*(1-discount_rate)

# %%
final
# Out:
# 664.56

# %%
r>100
# Out:
# True

# %%
mid_r = 100 < r < 300

# %%
mid_r
# Out:
# False

# %% [markdown]
# Parentheses (or round brackets) are essential in formulas because they explicitly define the order of operations, ensuring calculations are performed in a specific sequence to achieve the correct result. They act as a grouping tool that overrides the standard rules of precedence, allowing addition or subtraction to occur before multiplication or division.
