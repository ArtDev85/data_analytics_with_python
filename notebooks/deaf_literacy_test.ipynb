# %%
import pandas as pd
# Show all columns
pd.set_option("display.max_columns", None)
# from scipy.stats import chi2_contingency

# %%
# import os

# file_path = "/Users/aca/Desktop/ACA_Artashes/data_analytics_with_python/data/raw/deaf_dataset/deaf_data_sheet.xlsx"

# print(os.path.exists(file_path))

# %%
# df = pd.read_excel("deaf_data_sheet.xlsx")

# %%
df = pd.read_excel(
    "../data/raw/deaf_dataset/deaf_data_sheet.xlsx",
)

# %%
df.head()
# Out:
#    Unnamed: 0               Timestamp Հարցազրուցավարի անուն ազգանուն  \
# 0           1 2022-05-29 19:05:36.394                Անահիտ Դալալյան
# 1           2 2022-05-30 22:16:40.892                Անահիտ Դալալյան
# 2           3 2022-06-04 22:30:47.674                Անահիտ Դալալյան
# 3           4 2022-06-07 18:43:56.862                Անահիտ Դալալյան
# 4           5 2022-06-11 16:16:56.086                Անահիտ Դալալյան
#
#   Հարցազրույցը իրականացվել է՝ Հարցվողի անուն ազգանուն Հարցազրույցի ամսաթիվ  \
# 0                         NaN         Անգելինա Քառյան  2022-05-29 00:00:00
# 1                         NaN       Անահիտ Ղաբուզյան   2022-05-30 00:00:00
# 2                         NaN         Մալինա Խառատյան  2022-06-04 00:00:00
# 3                         NaN         Աննա Մարգարյան   2022-06-07 00:00:00
# 4                  Դեմ առ դեմ       Սվետլանա Սարգսյան  2022-06-11 00:00:00
#
#   A1. Նշե՛ք Ձեր մարզը: A2. Նշեք Ձեր բնակավայրի տիպը:  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 145 entries, 0 to 144
# Columns: 132 entries, Unnamed: 0 to Հարցազրույցը իրականացվել է՝.1
# dtypes: datetime64[us](1), float64(1), int64(1), object(8), str(121)
# memory usage: 149.7+ KB

# %%
df.describe()
# Out:
#        Unnamed: 0                   Timestamp  Unnamed: 96
# count  145.000000                         145          0.0
# mean    73.000000  2022-08-17 23:31:35.962227          NaN
# min      1.000000  2022-05-24 07:45:52.711000          NaN
# 25%     37.000000  2022-06-06 15:47:44.386000          NaN
# 50%     73.000000  2022-09-30 16:45:42.408000          NaN
# 75%    109.000000  2022-10-06 15:56:16.533000          NaN
# max    145.000000  2022-10-12 16:24:10.927000          NaN
# std     42.001984                         NaN          NaN

# %%
list(df.columns)
# Out:
# ['Unnamed: 0',
#  'Timestamp',
#  'Հարցազրուցավարի անուն ազգանուն',
#  'Հարցազրույցը իրականացվել է՝',
#  'Հարցվողի անուն ազգանուն',
#  'Հարցազրույցի ամսաթիվ',
#  'A1. Նշե՛ք Ձեր մարզը:',
#  'A2. Նշեք Ձեր բնակավայրի տիպը:',
#  'A3. Նշեք Ձեր բնակավայրի/վարչական շրջանի անունը:',
#  'A4. Հարցվողի սեռը:',
#  'A5. Նշե՛ք, խնդրեմ, Ձեր տարիքը:',
#  'A6. Նշե՛ք Ձեր ամուսնական կարգավիճակը',
#  'A7. Ու՞մ հետ եք բնակվում: ',
#  'A8. Ձեզ հետ բնակվող ընտանիքի անդամներից ովքե՞ր ունեն լսողության խնդիրներ: ',
#  'A9. Դուք Ձեզ համարում եք՝',
#  'A10. Առողջության բաղադրիչների վերաբերյալ դժվարություններ ունե՞ք: [Տեսողություն]',
#  'A10. Առողջության բաղադրիչների վերաբերյալ դժվարություններ ունե՞ք: [Հենաշարժողական վիճակ /քայլել, վազել/]',
#  'A10. Առողջության բաղադրիչների վերաբերյալ դժվարություններ ունե՞ք: [Հիշողություն և կենտրոնացում]',
#  'A10. Առողջության բաղադրիչների վերաբերյալ դժվարություններ ունե՞ք: [Խոսելու կարողություն]',
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                                                                                               0
# Timestamp                                                                                                0
# Հարցազրուցավարի անուն ազգանուն                                                                           0
# Հարցազրույցը իրականացվել է՝                                                                             38
# Հարցվողի անուն ազգանուն                                                                                  0
#                                                                                                       ...
# E6. Երբևէ դիմե՞լ եք հոգեբանի:                                                                            0
# E7. Ունե՞ք արդյոք հոգեբանի ծառայության կարիք:                                                            0
# Նշումների համար                                                                                         84
# ...

# %%
df.columns.tolist()
# Out:
# ['Unnamed: 0',
#  'Timestamp',
#  'Հարցազրուցավարի անուն ազգանուն',
#  'Հարցազրույցը իրականացվել է՝',
#  'Հարցվողի անուն ազգանուն',
#  'Հարցազրույցի ամսաթիվ',
#  'A1. Նշե՛ք Ձեր մարզը:',
#  'A2. Նշեք Ձեր բնակավայրի տիպը:',
#  'A3. Նշեք Ձեր բնակավայրի/վարչական շրջանի անունը:',
#  'A4. Հարցվողի սեռը:',
#  'A5. Նշե՛ք, խնդրեմ, Ձեր տարիքը:',
#  'A6. Նշե՛ք Ձեր ամուսնական կարգավիճակը',
#  'A7. Ու՞մ հետ եք բնակվում: ',
#  'A8. Ձեզ հետ բնակվող ընտանիքի անդամներից ովքե՞ր ունեն լսողության խնդիրներ: ',
#  'A9. Դուք Ձեզ համարում եք՝',
#  'A10. Առողջության բաղադրիչների վերաբերյալ դժվարություններ ունե՞ք: [Տեսողություն]',
#  'A10. Առողջության բաղադրիչների վերաբերյալ դժվարություններ ունե՞ք: [Հենաշարժողական վիճակ /քայլել, վազել/]',
#  'A10. Առողջության բաղադրիչների վերաբերյալ դժվարություններ ունե՞ք: [Հիշողություն և կենտրոնացում]',
#  'A10. Առողջության բաղադրիչների վերաբերյալ դժվարություններ ունե՞ք: [Խոսելու կարողություն]',
# ...

# %%
# df['new'] = df['']

# %%
df.head()
# Out:
#    Unnamed: 0               Timestamp Հարցազրուցավարի անուն ազգանուն  \
# 0           1 2022-05-29 19:05:36.394                Անահիտ Դալալյան
# 1           2 2022-05-30 22:16:40.892                Անահիտ Դալալյան
# 2           3 2022-06-04 22:30:47.674                Անահիտ Դալալյան
# 3           4 2022-06-07 18:43:56.862                Անահիտ Դալալյան
# 4           5 2022-06-11 16:16:56.086                Անահիտ Դալալյան
#
#   Հարցազրույցը իրականացվել է՝ Հարցվողի անուն ազգանուն Հարցազրույցի ամսաթիվ  \
# 0                         NaN         Անգելինա Քառյան  2022-05-29 00:00:00
# 1                         NaN       Անահիտ Ղաբուզյան   2022-05-30 00:00:00
# 2                         NaN         Մալինա Խառատյան  2022-06-04 00:00:00
# 3                         NaN         Աննա Մարգարյան   2022-06-07 00:00:00
# 4                  Դեմ առ դեմ       Սվետլանա Սարգսյան  2022-06-11 00:00:00
#
#   A1. Նշե՛ք Ձեր մարզը: A2. Նշեք Ձեր բնակավայրի տիպը:  \
# ...

# %%
# Show all columns
pd.set_option("display.max_columns", None)

# %% [markdown]
# ## 1. կրճատի նորմալ անուններ գրի սյուների անունները
# ## 2. պահի նրանք որոնք որ պետք են
# ## 3. դու էստեղ պետքա միաովորես պատասխանը` բաժանելով երկու մասի, լավ /վատ

# %% [markdown]
# ## Example

# %% [markdown]
# df_selected = df[
#     ["ID", "Gender", "Sign_Language", "Reading"]
# ]
#
# df_selected = df_selected.rename(
#     columns={
#         "Sign_Language": "language_type",
#         "Reading": "reading_score"
#     }
# )

# %%
df_selected = df[
    ["Unnamed: 0", "B2. Ինչպես կգնահատեք գրելու Ձեր կարողությունը: ", "B3. Ինչպես կգնահատեք կարդալու Ձեր կարողությունը: " ]
]

# %%
df_selected
# Out:
#      Unnamed: 0 B2. Ինչպես կգնահատեք գրելու Ձեր կարողությունը:   \
# 0             1                                      3. Բավարար
# 1             2                                      3. Բավարար
# 2             3                                          4. Վատ
# 3             4                                          4. Վատ
# 4             5                                      3. Բավարար
# ..          ...                                             ...
# 140         119                                          2. Լավ
# 141         142                                          2. Լավ
# 142         143                                          2. Լավ
# 143         144                                     1. Գերազանց
# 144         145                                          2. Լավ
#
#     B3. Ինչպես կգնահատեք կարդալու Ձեր կարողությունը:
# 0                                          3. Բավարար
# 1                                          3. Բավարար
# ...

# %%
df_selected.rename(columns={
    "Unnamed: 0" : "ID",
    "B3. Ինչպես կգնահատեք կարդալու Ձեր կարողությունը: " : "reading_score",
    "B2. Ինչպես կգնահատեք գրելու Ձեր կարողությունը: " : "writing_score"
}, inplace=True)

# Create a new column
df_selected["communication"] = ""

# Reorder columns
df_selected = df_selected[
    ["ID", "communication", "reading_score", "writing_score"]
]

# %%
df_selected
# Out:
#       ID communication reading_score writing_score
# 0      1                  3. Բավարար    3. Բավարար
# 1      2                  3. Բավարար    3. Բավարար
# 2      3                      4. Վատ        4. Վատ
# 3      4                  3. Բավարար        4. Վատ
# 4      5                      4. Վատ    3. Բավարար
# ..   ...           ...           ...           ...
# 140  119                      2. Լավ        2. Լավ
# 141  142                      2. Լավ        2. Լավ
# 142  143                      2. Լավ        2. Լավ
# 143  144                 1. Գերազանց   1. Գերազանց
# 144  145                      2. Լավ        2. Լավ
#
# [145 rows x 4 columns]

# %%
# list(df.columns)

# %%
df_selected.rename(columns={
    "A16. Որքան հաճախ եք կիրառում հաղորդակցության հետևյալ ձևերից յուրաքանչյուրը:   [Ժեստերով հաղորդկացվելը]" : "sign language",
    "A16. Որքան հաճախ եք կիրառում հաղորդակցության հետևյալ ձևերից յուրաքանչյուրը:   [Բանավոր շփումը ինքնուրույն]" : "spoken language"
}, inplace=True)

# %%
sign_col = "sign language"
spoken_col = "spoken language"
