# %% [markdown]
# ## Dates

# %% [markdown]
# ## Datetime

# %% [markdown]
# desription?

# %%
from datetime import datetime, date, timedelta

# %%
simple_date = date(2024, 7, 1)
simple_date
# Out:
# datetime.date(2024, 7, 1)

# %%
simple_date = date(day = 20, month = 10, year = 2025)
simple_date
# Out:
# datetime.date(2025, 10, 20)

# %%
simple_date.day
simple_date.year
simple_date.month
# Out:
# 10

# %%
if simple_date.day>15:
    print('Ամիսը կիսվավ')
else:
    print('Ամիսը նոր է սկսվել')
# Out:
# Ամիսը կիսվավ

# %%
datetime

# %%
.today()

# %%
if date.today().day>15:
    print('Ամիսը կիսվավ')
else:
    print('Ամիսը նոր է սկսվել')
# Out:
# Ամիսը նոր է սկսվել

# %%
campaign_day = date.today()

campaign_day
# Out:
# datetime.date(2026, 5, 10)

# %%
campaign_day = date.today()

campaign_day

# %%
datetime.now()
# Out:
# datetime.datetime(2026, 5, 10, 11, 10, 44, 957062)

# %%
dt.strftime("%Y/%m/%d/%H/")
dt
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 dt.strftime("%Y/%m/%d/%H/")
#       2 dt
#
# NameError: name 'dt' is not defined

# %%
start + timedelta(weeks=1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 start + timedelta(weeks=1)
#       2 start
#
# NameError: name 'start' is not defined
